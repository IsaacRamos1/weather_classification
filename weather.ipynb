# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(
    'dados_A312_D_2015-01-01_2024-12-31.csv',
    sep=';',  # Especifica o delimitador correto
    skiprows=9  # Ignora as 9 primeiras linhas
)

df = df.drop('Unnamed: 11', axis=1)

# %%
# ajustar o formato dos valores e substituir a vírgula pelo ponto

for coluna in df.columns:
    for i in range(len(df[coluna])):
        valor = df.at[i, coluna]
        if isinstance(valor, str):
            df.at[i, coluna] = valor.replace(',', '.')

for coluna in df.columns[1:]:
    try:
        df[coluna] = pd.to_numeric(df[coluna])
    except ValueError:
        pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 11 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Data Medicao                                            3653 non-null   object
#  1   PRECIPITACAO TOTAL, DIARIO (AUT)(mm)                    3065 non-null   float64
#  2   PRESSAO ATMOSFERICA MEDIA DIARIA (AUT)(mB)              3105 non-null   float64
#  3   TEMPERATURA DO PONTO DE ORVALHO MEDIA DIARIA (AUT)(°C)  3105 non-null   float64
#  4   TEMPERATURA MAXIMA, DIARIA (AUT)(°C)                    3138 non-null   float64
#  5   TEMPERATURA MEDIA, DIARIA (AUT)(°C)                     3064 non-null   float64
#  6   TEMPERATURA MINIMA, DIARIA (AUT)(°C)                    3143 non-null   float64
#  7   UMIDADE RELATIVA DO AR, MEDIA DIARIA (AUT)(%)           3215 non-null   float64
# ...

# %%
df.head()
# Out:
#   Data Medicao  PRECIPITACAO TOTAL, DIARIO (AUT)(mm)  \
# 0   2015-01-01                                   9.4
# 1   2015-01-02                                   0.0
# 2   2015-01-03                                   2.6
# 3   2015-01-04                                   4.0
# 4   2015-01-05                                   0.2
#
#    PRESSAO ATMOSFERICA MEDIA DIARIA (AUT)(mB)  \
# 0                                      1003.7
# 1                                      1003.3
# 2                                      1003.6
# 3                                      1004.7
# 4                                      1004.7
#
#    TEMPERATURA DO PONTO DE ORVALHO MEDIA DIARIA (AUT)(°C)  \
# 0                                               20.9
# 1                                               21.1
# 2                                               21.6
# 3                                               20.8
# 4                                               20.5
#
# ...
